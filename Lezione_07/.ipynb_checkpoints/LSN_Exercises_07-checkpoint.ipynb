# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 7</span>

# %% [markdown]
# ### Exercise 07.1
#
# Use the Monte Carlo NVT code we have provided to print out instantaneous values of potential energy per particle, $U/N$, and pressure, $P$, along **equilibrated** Monte Carlo simulations (of  $M=10^5$ MC steps and where the Metropolis acceptance ratio has been fixed approximately to 50%) in the following thermodynamic conditions:
# - solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# - liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# - gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)

# %% [markdown]
# 1. <span style="color:red">Once this data has been produced, compute and make pictures with a python script of the autocorrelation functions of $U/N$ and $P$ to obtain the Monte Carlo correlation time</span> via a fit with an exponential function. This will suggest you how large should be the blocks in your simulations.
# 2. Use the same data to study, with a python script, the estimation of the statistical uncertainties of the expectation value of $U/N$ and $P$ for different size of the blocks in the data blocking technique, from $L=M/N=10$ to $L=5\times 10^3$, being $N$ the number of blocks. <span style="color:red">Make pictures of these statistical uncertainties as a function of $L$.</span> What you observe in the statistical uncertainties after that the block size is large enough (from the point of view of the data blocking technique)?

# %% [markdown]
# #### Commenti: primo punto.
# tranne per la fase gassosa, per il calcolo delle funzioni di autocorrelazione ho utilizzato molti più punti di quelli che si possono osservare sull'asse delle ascisse.
# Ho voluto graficare solo una parte di tali funzioni poichè la parte più interessante è proprio quella iniziale.
# Graficando tutta la funzione si può osservare che quando t tende a tmax, l'autocorrelazione dà delle previsioni errate;
# si osservano delle pesanti fluttuazioni.
#
# Una volta trovate tali funzioni, si può stimare il tempo di correlazione.

# %%
def func(x, a, b, c):
     return a * np.exp(-b * x) + c

x_data, y_data=np.loadtxt("./Es7.1./Es7.1.a./Solido/CorrelazionePotenziale", usecols=(0,1), delimiter='  ', unpack='true')
plt.plot(x_data, y_data)
plt.xlabel('t')
plt.ylabel('$\chi(r)$')
plt.title('Autocorrelation function of $U/N$: solid phase')

popt, pcov = curve_fit(func, x_data, y_data)
print(popt)

plt.plot(x_data, func(x_data, *popt),color="r")
plt.grid(True)
plt.show()

x_data, y_data=np.loadtxt("./Es7.1./Es7.1.a./Solido/CorrelazionePressione", usecols=(0,1), delimiter='  ', unpack='true')
plt.plot(x_data, y_data)
plt.xlabel('t')
plt.ylabel('$\chi(r)$')
plt.title('Autocorrelation function of $P$: solid phase')

popt, pcov = curve_fit(func, x_data, y_data)
print(popt)

plt.plot(x_data, func(x_data, *popt),color="r")
plt.grid(True)
plt.show()
# Out:
# [ 0.95944907  0.11008301 -0.02379896]
# [ 0.96098219  0.11009429 -0.02449547]

# %%
def func(x, a, b, c):
     return a * np.exp(-b * x) + c

x_data, y_data=np.loadtxt("./Es7.1./Es7.1.a./Liquido/CorrelazionePotenziale", usecols=(0,1), delimiter='  ', unpack='true')
plt.plot(x_data, y_data)
plt.xlabel('t')
plt.ylabel('$\chi(r)$')
plt.title('Autocorrelation function of $U/N$: liquid phase')

popt, pcov = curve_fit(func, x_data, y_data)
print(popt)

plt.plot(x_data, func(x_data, *popt),color="r")
plt.grid(True)
plt.show()


x_data, y_data=np.loadtxt("./Es7.1./Es7.1.a./Liquido/CorrelazionePressione", usecols=(0,1), delimiter='  ', unpack='true')
plt.plot(x_data, y_data)
plt.xlabel('t')
plt.ylabel('$\chi(r)$')
plt.title('Autocorrelation function of $P$: liquid phase')

popt, pcov = curve_fit(func, x_data, y_data)
print(popt)

plt.plot(x_data, func(x_data, *popt),color="r")
plt.grid(True)
plt.show()
# Out:
# [ 0.76621612  0.01432318 -0.04008597]
# [0.77160304 0.0143613  0.00319399]

# %%
def func(x, a, b, c):
     return a * np.exp(-b * x) + c

x_data, y_data=np.loadtxt("./Es7.1./Es7.1.a./Gassoso/CorrelazionePotenziale", usecols=(0,1), delimiter='  ', unpack='true')
plt.plot(x_data, y_data)
plt.xlabel('t')
plt.ylabel('$\chi(r)$')
plt.title('Autocorrelation function of $U/N$: gas phase')

popt, pcov = curve_fit(func, x_data, y_data)
print(popt)

plt.plot(x_data, func(x_data, *popt),color="r")
plt.grid(True)
plt.show()

x_data, y_data=np.loadtxt("./Es7.1./Es7.1.a./Gassoso/CorrelazionePressione", usecols=(0,1), delimiter='  ', unpack='true')
plt.plot(x_data, y_data)
plt.xlabel('t')
plt.ylabel('$\chi(r)$')
plt.title('Autocorrelation function of $P$: gas phase')

popt, pcov = curve_fit(func, x_data, y_data)
print(popt)

plt.plot(x_data, func(x_data, *popt),color="r")
plt.grid(True)
plt.show()
# Out:
# [ 1.01085755  0.00219037 -0.1219684 ]
# [ 0.83764157  0.17440735 -0.00527509]

# %%
tUSolid,tPSolid=np.loadtxt("./Es7.1./Es7.1.a./Solido/TempiDiCorrelazione", usecols=(0),  unpack='true')
tULiquid,tPLiquid=np.loadtxt("./Es7.1./Es7.1.a./Liquido/TempiDiCorrelazione", usecols=(0), unpack='true')
tUGas,tPGas=np.loadtxt("./Es7.1./Es7.1.a./Gassoso/TempiDiCorrelazione", usecols=(0), unpack='true')

print("Fase solida: tempi di correlazione per U/N=" ,tUSolid, "steps e pressione=", tPSolid, "steps")
print("Fase liquida: tempi di correlazione per U/N=" ,tULiquid, "steps e pressione=", tPLiquid, "steps")
print("Fase gassosa: tempi di correlazione per U/N=" ,tUGas, "steps e pressione=", tPGas, "steps")
# Out:
# Fase solida: tempi di correlazione per U/N= 8.0 steps e pressione= 8.0 steps
# Fase liquida: tempi di correlazione per U/N= 59.0 steps e pressione= 62.0 steps
# Fase gassosa: tempi di correlazione per U/N= 330.0 steps e pressione= 4.0 steps

# %% [markdown]
# I blocchi dovranno contenere un numero di steps maggiori di quelli associati al tempo di correlazione.
# In questo modo, le misure saranno sufficientemente scorrelate.

# %% [markdown]
# #### Commenti: secondo punto.
# Per avere un'accettanza di circa il 50%, ho selezionato diversi intervalli temporali tra due mosse in base allo stato
# del sistema.
#
# I punti dei grafici immediatamente sottostanti sono stati ricavati dagli errori ottenuti dall'ultimo
# blocco all'interno della simulazione al variare della loro lunghezza.
# É importante sottolineare che all,aumentare della lunghezza dei blocchi, l'errore diminuisce.
# Questo si può dedurre dal fatto che avendo più dati, le misure saranno più precise.

# %%
x, y=np.loadtxt("./Es7.1./Es7.1.b./Solido/output.epotLAST.0", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x, y, marker=".")
plt.xlabel('L')
plt.ylabel('Errore $U/N$')
plt.title('Errore del potenziale per particella al variare della lunghezza del blocco: fase solida')

plt.grid(True)
plt.show()

x, y=np.loadtxt("./Es7.1./Es7.1.b./Solido/output.presLAST.0", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x, y, marker=".")
plt.xlabel('L')
plt.ylabel('Errore $P$')
plt.title('Errore della pressione al variare della lunghezza del blocco: fase solida')

plt.grid(True)
plt.show()

# %%
x, y=np.loadtxt("./Es7.1./Es7.1.b./Liquido/output.epotLAST.0", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x, y, marker=".")
plt.xlabel('L')
plt.ylabel('Errore $U/N$')
plt.title('Errore del potenziale per particella al variare della lunghezza del blocco: fase liquida')

plt.grid(True)
plt.show()

x, y=np.loadtxt("./Es7.1./Es7.1.b./Liquido/output.presLAST.0", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x, y, marker=".")
plt.xlabel('L')
plt.ylabel('Errore $P$')
plt.title('Errore della pressione al variare della lunghezza del blocco: fase liquida')

plt.grid(True)
plt.show()

# %%
x, y=np.loadtxt("./Es7.1./Es7.1.b./Gassoso/output.epotLAST.0", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x, y, marker=".")
plt.xlabel('L')
plt.ylabel('Errore $U/N$')
plt.title('Errore del potenziale per particella al variare della lunghezza del blocco: fase gassosa')

plt.grid(True)
plt.show()

x, y=np.loadtxt("./Es7.1./Es7.1.b./Gassoso/output.presLAST.0", usecols=(0,1), delimiter=' ', unpack='true')
plt.plot(x, y, marker=".")
plt.xlabel('L')
plt.ylabel('Errore $P$')
plt.title('Errore della pressione al variare della lunghezza del blocco: fase gassosa')

plt.grid(True)
plt.show()

# %% [markdown]
# Si può affermare che un numero di passi pari a mille può essere considerato una scelta scelta ragionevole per il calcolo
# dei parametri termodinamici.

# %% [markdown]
# ### Exercise 07.2
#
# <span style="color:red">Include the calculation of the radial distribution function, $g(r)$, as a function of the radial distance $r$ among particles, with $r \in \left[ 0; L/2\right]$ inside the Monte Carlo NVT code</span> we have provided: average value of $g(r)$ in each block (with output in the file: output.gofr.0), final average value of $g(r)$ with statistical uncertainties (with output in the file: output.gave.0).

# %% [markdown]
# ### Exercise 07.3
#
# <span style="color:red">Include the calculation of the radial distribution function, $g(r)$, inside the previously used Molecular Dynamics code</span>.

# %% [markdown]
# ### Exercise 07.4
#
# By means of your upgraded MC code, equilibrate and <span style="color:red">perform MC NVT simulations via a Lennard-Jones model</span> of Argon ($\sigma = 0.34$ nm, $\epsilon/k_B = 120$ K, $m=39.948$ amu) and Krypton ($\sigma = 0.364$ nm, $\epsilon/k_B = 164$ K, $m=83.798$ amu) in the following conditions:
# 1. solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# 2. liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# 3. gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)
#
# <span style="color:red">show in pictures the obtained average values and uncertainties for the potential energy per particle, $U/N$, the pressure $P$ and the radial distribution function $g(r)$ in SI units ... and compare your MC results for the radial distribution function, $g(r)$, with those obtained with Molecular Dynamics NVE simulations in similar thermodynamic conditions.</span>

# %% [markdown]
# #### Commenti.
#
# Le figure sottostanti rappresentano i valori della pressione e dell'energia potenziale per particella ottenuti.

# %%
# plot with various axes scales
plt.figure(1)

print("             Parametri termodinamici ottenuti con l'algortimo di Metropolis: fase solida")

plt.subplot(411)
z, f, error = np.loadtxt("./Es7.4./MC/Solido/Argon/output.epot.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$U/N$ [J]')
plt.title('Energia potenziale per particella: Argon')
plt.grid(True)

plt.subplot(412)
z, f, error = np.loadtxt("./Es7.4./MC/Solido/Argon/output.pres.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$P$ $[N]/[m^-2]$')
plt.title('Pressione: Argon')
plt.grid(True)

plt.subplot(413)
z, f, error = np.loadtxt("./Es7.4./MC/Solido/Krypton/output.epot.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$U/N$ [J]')
plt.title('Energia potenziale per particella: Krypton')
plt.grid(True)

plt.subplot(414)
z, f, error = np.loadtxt("./Es7.4./MC/Solido/Krypton/output.pres.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$P$ $[N]/[m^-2]$')
plt.title('Pressione: Krypton')
plt.grid(True)

plt.subplots_adjust(top=4, bottom=0.5, left=1, right=2, hspace=0.3,
                    wspace=0.25)

plt.show()
# Out:
#              Parametri termodinamici ottenuti con l'algortimo di Metropolis: fase solida

# %%
# plot with various axes scales
plt.figure(1)

print("             Parametri termodinamici ottenuti con l'algortimo di Metropolis: fase liquida")

plt.subplot(411)
z, f, error = np.loadtxt("./Es7.4./MC/Liquido/Argon/output.epot.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$U/N$ [J]')
plt.title('Energia potenziale per particella: Argon')
plt.grid(True)

plt.subplot(412)
z, f, error = np.loadtxt("./Es7.4./MC/Liquido/Argon/output.pres.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$P$ $[N]/[m^-2]$')
plt.title('Pressione: Argon')
plt.grid(True)

plt.subplot(413)
z, f, error = np.loadtxt("./Es7.4./MC/Liquido/Krypton/output.epot.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$U/N$ [J]')
plt.title('Energia potenziale per particella: Krypton')
plt.grid(True)

plt.subplot(414)
z, f, error = np.loadtxt("./Es7.4./MC/Liquido/Krypton/output.pres.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$P$ $[N]/[m^-2]$')
plt.title('Pressione: Krypton')
plt.grid(True)

plt.subplots_adjust(top=4, bottom=0.5, left=1, right=2, hspace=0.3,
                    wspace=0.25)

plt.show()
# Out:
#              Parametri termodinamici ottenuti con l'algortimo di Metropolis: fase liquida

# %%
# plot with various axes scales
plt.figure(1)

print("             Parametri termodinamici ottenuti con l'algortimo di Metropolis: fase gassosa")

plt.subplot(411)
z, f, error = np.loadtxt("./Es7.4./MC/Gassoso/Argon/output.epot.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$U/N$ [J]')
plt.title('Energia potenziale per particella: Argon')
plt.grid(True)

plt.subplot(412)
z, f, error = np.loadtxt("./Es7.4./MC/Gassoso/Argon/output.pres.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$P$ $[N]/[m^-2]$')
plt.title('Pressione: Argon')
plt.grid(True)

plt.subplot(413)
z, f, error = np.loadtxt("./Es7.4./MC/Gassoso/Krypton/output.epot.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$U/N$ [J]')
plt.title('Energia potenziale per particella: Krypton')
plt.grid(True)

plt.subplot(414)
z, f, error = np.loadtxt("./Es7.4./MC/Gassoso/Krypton/output.pres.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error)
plt.xlabel('N')
plt.ylabel('$P$ $[N]/[m^-2]$')
plt.title('Pressione: Krypton')
plt.grid(True)

plt.subplots_adjust(top=4, bottom=0.5, left=1, right=2, hspace=0.3,
                    wspace=0.25)

plt.show()
# Out:
#              Parametri termodinamici ottenuti con l'algortimo di Metropolis: fase gassosa

# %%
print("             g(r) ottenuta con l'algortimo di Metropolis: fase solida")

z, f, error = np.loadtxt("./Es7.4./MC/Solido/Argon/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error, marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Argon')
plt.grid(True)
plt.show()

z, f, error = np.loadtxt("./Es7.4./MC/Solido/Krypton/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error ,marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Krypton')
plt.grid(True)
plt.show()

print("             g(r) ottenuta con l'algortimo di Verlet: fase solida")
z, f, error = np.loadtxt("./Es7.4./MolecularDynamics/Solido/Argon/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error, marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Argon')
plt.grid(True)
plt.show()

z, f, error = np.loadtxt("./Es7.4./MolecularDynamics/Solido/Krypton/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error ,marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Krypton')
plt.grid(True)
plt.show()
# Out:
#              g(r) ottenuta con l'algortimo di Metropolis: fase solida
#              g(r) ottenuta con l'algortimo di Verlet: fase solida

# %%
print("             g(r) ottenuta con l'algortimo di Metropolis: fase liquida")

z, f, error = np.loadtxt("./Es7.4./MC/Liquido/Argon/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error, marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Argon')
plt.grid(True)
plt.show()

z, f, error = np.loadtxt("./Es7.4./MC/Liquido/Krypton/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error ,marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Krypton')
plt.grid(True)
plt.show()

print("             g(r) ottenuta con l'algortimo di Verlet: fase liquida")
z, f, error = np.loadtxt("./Es7.4./MolecularDynamics/Liquido/Argon/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error, marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Argon')
plt.grid(True)
plt.show()

z, f, error = np.loadtxt("./Es7.4./MolecularDynamics/Liquido/Krypton/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error ,marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Krypton')
plt.grid(True)
plt.show()
# Out:
#              g(r) ottenuta con l'algortimo di Metropolis: fase liquida
#              g(r) ottenuta con l'algortimo di Verlet: fase liquida

# %%
print("             g(r) ottenuta con l'algortimo di Metropolis: fase gassosa")

z, f, error = np.loadtxt("./Es7.4./MC/Gassoso/Argon/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error, marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Argon')
plt.grid(True)
plt.show()

z, f, error = np.loadtxt("./Es7.4./MC/Gassoso/Krypton/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error ,marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Krypton')
plt.grid(True)
plt.show()

print("             g(r) ottenuta con l'algortimo di Verlet: fase gassosa")
z, f, error = np.loadtxt("./Es7.4./MolecularDynamics/Gassoso/Argon/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error, marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Argon')
plt.grid(True)
plt.show()

z, f, error = np.loadtxt("./Es7.4./MolecularDynamics/Gassoso/Krypton/output.gofrFinale.0", usecols=(0,1,2), delimiter=' ', unpack='true')
plt.errorbar(z,f,yerr=error ,marker=".")
plt.xlabel('N')
plt.ylabel('$g(r)$')
plt.title('g(r): Krypton')
plt.grid(True)
plt.show()
# Out:
#              g(r) ottenuta con l'algortimo di Metropolis: fase gassosa
#              g(r) ottenuta con l'algortimo di Verlet: fase gassosa
